# %%
CLASS_BERT_TEXT = {
    # 기본 상태 (깨끗한 것) 9개
    'c_1': [
        "표면이 깨끗하게 유지된 상태입니다",
        "오염 없이 건조한 상태입니다",
        "이물질 없이 양호한 상태입니다",
        "잔여물 없이 청결합니다",
        "젖지 않고 깨끗한 상태입니다",
        "찢김 없이 온전한 상태입니다",
        "오염된 흔적이 없는 상태입니다",
        "냄새 없이 깨끗한 상태입니다",
        "부착물 없이 깨끗합니다",
        "세척된 깨끗한 상태입니다",
        "건조하고 청결한 상태입니다",
        "변형 없이 깨끗한 상태입니다",
        "얼룩 없이 깨끗한 상태입니다",
        "오물 없이 양호합니다",
        "깨끗하게 비워진 상태입니다",
        "손상 없이 청결합니다",
        "흔적 없이 깨끗한 상태입니다",
        "잘 정리된 깨끗한 상태입니다",
        "오염물 없이 보관된 상태입니다",
        "깨끗하게 처리된 상태입니다",
    ],
    'c_2_01': [
        "내부가 비워진 깨끗한 상태입니다",
        "세척되어 청결한 상태입니다",
        "잔여물 없이 건조합니다",
        "오염 없이 양호한 상태입니다",
        "깨끗하게 비워진 상태입니다",
        "이물질 없이 깨끗합니다",
        "냄새 없이 청결한 상태입니다",
        "손상 없이 깨끗한 상태입니다",
        "얼룩 없이 양호합니다",
        "건조하고 깨끗한 상태입니다",
        "오물 없이 청결합니다",
        "변형 없이 깨끗한 상태입니다",
        "흔적 없이 양호한 상태입니다",
        "세척 후 건조된 상태입니다",
        "오염물 없이 깨끗합니다",
        "부착물 없이 양호합니다",
        "깨끗하게 관리된 상태입니다",
        "청결하게 유지된 상태입니다",
        "잘 세척된 깨끗한 상태입니다",
        "오염 흔적 없이 깨끗합니다",
    ],
    'c_2_02': [
        "내부가 깨끗하게 비워진 상태입니다",
        "잔여물 없이 건조한 상태입니다",
        "세척되어 깨끗한 상태입니다",
        "오염 없이 청결합니다",
        "이물질 없이 양호한 상태입니다",
        "냄새 없이 깨끗합니다",
        "건조하고 청결한 상태입니다",
        "얼룩 없이 깨끗한 상태입니다",
        "오물 없이 양호합니다",
        "손상 없이 깨끗한 상태입니다",
        "흔적 없이 청결합니다",
        "변형 없이 양호한 상태입니다",
        "깨끗하게 정리된 상태입니다",
        "세척 후 양호한 상태입니다",
        "오염물 없이 청결합니다",
        "부착물 없이 깨끗합니다",
        "청결하게 비워진 상태입니다",
        "잘 관리된 깨끗한 상태입니다",
        "오염 흔적 없이 양호합니다",
        "깨끗하게 처리된 상태입니다",
    ],
    'c_3': [
        "내부가 깨끗하게 비워진 상태입니다",
        "세척되어 오염 없는 상태입니다",
        "잔여물 없이 청결합니다",
        "건조하고 깨끗한 상태입니다",
        "이물질 없이 양호합니다",
        "냄새 없이 깨끗한 상태입니다",
        "얼룩 없이 청결합니다",
        "오물 없이 깨끗한 상태입니다",
        "손상 없이 양호합니다",
        "변형 없이 깨끗한 상태입니다",
        "흔적 없이 양호한 상태입니다",
        "오염물 없이 깨끗합니다",
        "부착물 없이 청결합니다",
        "깨끗하게 비워진 상태입니다",
        "세척 후 깨끗한 상태입니다",
        "청결하게 관리된 상태입니다",
        "잘 세척된 상태입니다",
        "오염 흔적 없이 깨끗합니다",
        "깨끗하게 정리된 상태입니다",
        "청결하게 처리된 상태입니다",
    ],
    'c_4_01_02': [
        "내부가 세척된 깨끗한 상태입니다",
        "잔여물 없이 투명한 상태입니다",
        "오염 없이 깨끗합니다",
        "건조하고 청결한 상태입니다",
        "이물질 없이 양호합니다",
        "냄새 없이 깨끗한 상태입니다",
        "얼룩 없이 투명합니다",
        "오물 없이 양호한 상태입니다",
        "손상 없이 깨끗합니다",
        "변형 없이 청결한 상태입니다",
        "흔적 없이 깨끗합니다",
        "오염물 없이 양호합니다",
        "부착물 없이 깨끗한 상태입니다",
        "세척 후 깨끗한 상태입니다",
        "청결하게 비워진 상태입니다",
        "잘 세척된 양호한 상태입니다",
        "오염 흔적 없이 투명합니다",
        "깨끗하게 관리된 상태입니다",
        "청결하게 정리된 상태입니다",
        "깨끗하게 처리된 상태입니다",
    ],
    'c_4_02_01_02': [
        "내부가 깨끗하게 비워진 상태입니다",
        "잔여물 없이 청결합니다",
        "오염 없이 투명한 상태입니다",
        "건조하고 깨끗한 상태입니다",
        "이물질 없이 청결합니다",
        "냄새 없이 양호한 상태입니다",
        "얼룩 없이 깨끗합니다",
        "오물 없이 청결한 상태입니다",
        "손상 없이 양호합니다",
        "변형 없이 깨끗한 상태입니다",
        "흔적 없이 청결합니다",
        "오염물 없이 깨끗합니다",
        "부착물 없이 양호한 상태입니다",
        "세척 후 청결한 상태입니다",
        "깨끗하게 비워진 상태입니다",
        "잘 관리된 깨끗한 상태입니다",
        "오염 흔적 없이 양호합니다",
        "청결하게 처리된 상태입니다",
        "깨끗하게 정리된 상태입니다",
        "청결하게 관리된 상태입니다",
    ],
    'c_4_02_02_02': [
        "내부가 깨끗하게 비워진 상태입니다",
        "잔여물 없이 청결합니다",
        "오염 없이 투명한 상태입니다",
        "건조하고 깨끗한 상태입니다",
        "이물질 없이 청결합니다",
        "냄새 없이 양호한 상태입니다",
        "얼룩 없이 깨끗합니다",
        "오물 없이 청결한 상태입니다",
        "손상 없이 양호합니다",
        "변형 없이 깨끗한 상태입니다",
        "흔적 없이 청결합니다",
        "오염물 없이 깨끗합니다",
        "부착물 없이 양호한 상태입니다",
        "세척 후 청결한 상태입니다",
        "깨끗하게 비워진 상태입니다",
        "잘 관리된 깨끗한 상태입니다",
        "오염 흔적 없이 양호합니다",
        "청결하게 처리된 상태입니다",
        "깨끗하게 정리된 상태입니다",
        "청결하게 관리된 상태입니다",
    ],
    'c_4_02_03_02': [
        "내부가 깨끗하게 비워진 상태입니다",
        "잔여물 없이 청결합니다",
        "오염 없이 투명한 상태입니다",
        "건조하고 깨끗한 상태입니다",
        "이물질 없이 청결합니다",
        "냄새 없이 양호한 상태입니다",
        "얼룩 없이 깨끗합니다",
        "오물 없이 청결한 상태입니다",
        "손상 없이 양호합니다",
        "변형 없이 깨끗한 상태입니다",
        "흔적 없이 청결합니다",
        "오염물 없이 깨끗합니다",
        "부착물 없이 양호한 상태입니다",
        "세척 후 청결한 상태입니다",
        "깨끗하게 비워진 상태입니다",
        "잘 관리된 깨끗한 상태입니다",
        "오염 흔적 없이 양호합니다",
        "청결하게 처리된 상태입니다",
        "깨끗하게 정리된 상태입니다",
        "청결하게 관리된 상태입니다",
    ],
    'c_4_03': [
        "내부가 깨끗하게 비워진 상태입니다",
        "잔여물 없이 청결합니다",
        "오염 없이 투명한 상태입니다",
        "건조하고 깨끗한 상태입니다",
        "이물질 없이 청결합니다",
        "냄새 없이 양호한 상태입니다",
        "얼룩 없이 깨끗합니다",
        "오물 없이 청결한 상태입니다",
        "손상 없이 양호합니다",
        "변형 없이 깨끗한 상태입니다",
        "흔적 없이 청결합니다",
        "오염물 없이 깨끗합니다",
        "부착물 없이 양호한 상태입니다",
        "세척 후 청결한 상태입니다",
        "깨끗하게 비워진 상태입니다",
        "잘 관리된 깨끗한 상태입니다",
        "오염 흔적 없이 양호합니다",
        "청결하게 처리된 상태입니다",
        "깨끗하게 정리된 상태입니다",
        "청결하게 관리된 상태입니다",
    ],
    'c_5_02': [
        "내부가 깨끗하게 비워진 상태입니다",
        "잔여물 없이 투명한 상태입니다",
        "세척되어 청결한 상태입니다",
        "건조하고 깨끗한 상태입니다",
        "이물질 없이 양호합니다",
        "냄새 없이 깨끗한 상태입니다",
        "얼룩 없이 투명합니다",
        "오물 없이 깨끗한 상태입니다",
        "손상 없이 청결합니다",
        "변형 없이 깨끗한 상태입니다",
        "흔적 없이 양호합니다",
        "오염물 없이 투명한 상태입니다",
        "부착물 없이 깨끗합니다",
        "세척 후 투명한 상태입니다",
        "청결하게 비워진 상태입니다",
        "잘 세척된 깨끗한 상태입니다",
        "오염 흔적 없이 투명합니다",
        "깨끗하게 관리된 상태입니다",
        "청결하게 정리된 상태입니다",
        "깨끗하게 처리된 상태입니다",
    ],
    'c_6': [
        "내부가 세척된 깨끗한 상태입니다",
        "잔여물 없이 청결합니다",
        "오염 없이 깨끗한 상태입니다",
        "건조하고 양호한 상태입니다",
        "이물질 없이 깨끗합니다",
        "냄새 없이 청결한 상태입니다",
        "얼룩 없이 양호합니다",
        "오물 없이 깨끗한 상태입니다",
        "손상 없이 청결합니다",
        "변형 없이 양호한 상태입니다",
        "흔적 없이 깨끗합니다",
        "오염물 없이 청결한 상태입니다",
        "부착물 없이 양호합니다",
        "세척 후 깨끗한 상태입니다",
        "청결하게 비워진 상태입니다",
        "잘 관리된 양호한 상태입니다",
        "오염 흔적 없이 깨끗합니다",
        "깨끗하게 처리된 상태입니다",
        "청결하게 관리된 상태입니다",
        "깨끗하게 정리된 상태입니다",
    ],
    'c_7': [
        "내용물 없이 깨끗한 상태입니다",
        "잔여물 없이 청결합니다",
        "오염 없이 투명한 상태입니다",
        "건조하고 깨끗한 상태입니다",
        "이물질 없이 양호합니다",
        "냄새 없이 깨끗한 상태입니다",
        "얼룩 없이 투명합니다",
        "오물 없이 양호한 상태입니다",
        "손상 없이 깨끗합니다",
        "찢김 없이 양호한 상태입니다",
        "흔적 없이 깨끗합니다",
        "오염물 없이 양호합니다",
        "부착물 없이 깨끗한 상태입니다",
        "세척 후 깨끗한 상태입니다",
        "청결하게 비워진 상태입니다",
        "잘 관리된 깨끗한 상태입니다",
        "오염 흔적 없이 양호합니다",
        "깨끗하게 처리된 상태입니다",
        "청결하게 정리된 상태입니다",
        "깨끗하게 관리된 상태입니다",
    ],

    # 이물질 있는 것 8개
    'c_1_01': [
        "표면에 오염된 흔적이 있습니다",
        "이물질이 스며든 상태입니다",
        "오염으로 인해 변색된 상태입니다",
        "음식물이 묻어있는 상태입니다",
        "기름기가 남아있는 상태입니다",
        "액체가 흡수된 상태입니다",
        "오물이 부착된 상태입니다",
        "찌꺼기가 남아있는 상태입니다",
        "세척이 필요한 오염 상태입니다",
        "이물질로 인해 변질된 상태입니다",
        "오염물이 묻어있는 상태입니다",
        "잔여물이 남아있는 상태입니다",
        "더러운 흔적이 있는 상태입니다",
        "오염되어 처리가 필요한 상태입니다",
        "이물질이 부착된 상태입니다",
        "냄새가 날 수 있는 오염 상태입니다",
        "오물로 인해 손상된 상태입니다",
        "세척되지 않은 오염 상태입니다",
        "불순물이 묻어있는 상태입니다",
        "오염으로 인해 재활용이 어려운 상태입니다",
    ],
    'c_2_02_01': [
        "내부에 잔여물이 남아있는 상태입니다",
        "음료 찌꺼기가 있는 상태입니다",
        "오염된 흔적이 내부에 있습니다",
        "세척이 필요한 상태입니다",
        "이물질이 남아있는 상태입니다",
        "내용물이 묻어있는 상태입니다",
        "오물이 잔류한 상태입니다",
        "찌꺼기가 부착된 상태입니다",
        "오염물이 남아있는 상태입니다",
        "더러운 흔적이 있는 상태입니다",
        "냄새가 나는 오염 상태입니다",
        "잔여 오염물이 있는 상태입니다",
        "세척되지 않은 상태입니다",
        "불순물이 남아있는 상태입니다",
        "오염으로 처리가 필요한 상태입니다",
        "내부가 오염된 상태입니다",
        "이물질로 오염된 상태입니다",
        "잔류물이 있는 상태입니다",
        "오물이 묻어있는 상태입니다",
        "오염되어 재활용이 어려운 상태입니다",
    ],
    'c_3_01': [
        "내부에 음식물이 남아있는 상태입니다",
        "오염된 잔여물이 있는 상태입니다",
        "이물질이 내부에 있는 상태입니다",
        "세척이 필요한 오염 상태입니다",
        "음식 찌꺼기가 남아있는 상태입니다",
        "기름기가 묻어있는 상태입니다",
        "오물이 부착된 상태입니다",
        "내용물이 남아있는 상태입니다",
        "오염물이 잔류한 상태입니다",
        "더러운 흔적이 있는 상태입니다",
        "냄새가 나는 오염 상태입니다",
        "잔여 이물질이 있는 상태입니다",
        "세척되지 않은 상태입니다",
        "불순물이 있는 상태입니다",
        "오염으로 처리가 필요한 상태입니다",
        "내부가 오염된 상태입니다",
        "이물질로 오염된 상태입니다",
        "잔류 오염물이 있는 상태입니다",
        "오물이 남아있는 상태입니다",
        "오염되어 재활용이 어려운 상태입니다",
    ],
    'c_4_03_01': [
        "내부에 오염물이 있는 상태입니다",
        "이물질이 부착된 상태입니다",
        "세척이 필요한 상태입니다",
        "오염된 흔적이 있는 상태입니다",
        "잔여물이 남아있는 상태입니다",
        "음식물이 묻어있는 상태입니다",
        "오물이 잔류한 상태입니다",
        "찌꺼기가 있는 상태입니다",
        "오염물이 남아있는 상태입니다",
        "더러운 흔적이 있는 상태입니다",
        "냄새가 나는 오염 상태입니다",
        "내부가 오염된 상태입니다",
        "세척되지 않은 오염 상태입니다",
        "불순물이 있는 상태입니다",
        "오염으로 처리가 필요한 상태입니다",
        "이물질로 오염된 상태입니다",
        "잔류물이 있는 상태입니다",
        "오물이 묻어있는 상태입니다",
        "오염되어 재활용이 어려운 상태입니다",
        "이물질이 남아있는 상태입니다",
    ],
    'c_5_01_01': [
        "내부에 오염물이 있고 포장재가 결합된 상태입니다",
        "이물질과 포장재가 함께 있는 상태입니다",
        "오염되고 분리가 필요한 상태입니다",
        "잔여물과 포장재가 있는 상태입니다",
        "음식물과 포장재가 결합된 상태입니다",
        "오물과 포장이 혼재된 상태입니다",
        "찌꺼기와 포장재가 있는 상태입니다",
        "오염물과 포장이 있는 상태입니다",
        "더러운 흔적과 포장재가 있습니다",
        "냄새와 포장재가 있는 상태입니다",
        "내부 오염과 포장이 있는 상태입니다",
        "세척과 분리가 필요한 상태입니다",
        "불순물과 포장재가 있는 상태입니다",
        "오염과 포장으로 처리가 필요한 상태입니다",
        "이물질과 포장이 있는 상태입니다",
        "잔류물과 포장재가 있는 상태입니다",
        "오물과 포장이 있는 상태입니다",
        "오염과 포장재가 혼재된 상태입니다",
        "이물질과 포장으로 재활용이 어려운 상태입니다",
        "오염되고 포장이 결합된 상태입니다",
    ],
    'c_5_02_01': [
        "내부에 잔여물이 남아있는 상태입니다",
        "오염된 흔적이 있는 상태입니다",
        "이물질이 남아있는 상태입니다",
        "세척이 필요한 오염 상태입니다",
        "음료 잔여물이 있는 상태입니다",
        "기름기가 남아있는 상태입니다",
        "오물이 잔류한 상태입니다",
        "찌꺼기가 있는 상태입니다",
        "오염물이 남아있는 상태입니다",
        "더러운 흔적이 있는 상태입니다",
        "냄새가 나는 오염 상태입니다",
        "내부가 오염된 상태입니다",
        "세척되지 않은 상태입니다",
        "불순물이 있는 상태입니다",
        "오염으로 처리가 필요한 상태입니다",
        "이물질로 오염된 상태입니다",
        "잔류물이 있는 상태입니다",
        "오물이 묻어있는 상태입니다",
        "오염되어 재활용이 어려운 상태입니다",
        "이물질이 내부에 있는 상태입니다",
    ],
    'c_6_01': [
        "내부에 음식물이 남아있는 상태입니다",
        "기름기가 묻어있는 상태입니다",
        "오염된 흔적이 있는 상태입니다",
        "이물질이 남아있는 상태입니다",
        "세척이 필요한 오염 상태입니다",
        "음식 찌꺼기가 있는 상태입니다",
        "오물이 부착된 상태입니다",
        "내용물이 남아있는 상태입니다",
        "오염물이 잔류한 상태입니다",
        "더러운 흔적이 있는 상태입니다",
        "냄새가 나는 오염 상태입니다",
        "잔여 이물질이 있는 상태입니다",
        "세척되지 않은 상태입니다",
        "불순물이 있는 상태입니다",
        "오염으로 처리가 필요한 상태입니다",
        "내부가 오염된 상태입니다",
        "이물질로 오염된 상태입니다",
        "잔류 오염물이 있는 상태입니다",
        "오물이 남아있는 상태입니다",
        "오염되어 재활용이 어려운 상태입니다",
    ],
    'c_7_01': [
        "내용물이 남아있어 오염된 상태입니다",
        "이물질이 묻어있는 상태입니다",
        "오염된 흔적이 있는 상태입니다",
        "세척이 필요한 상태입니다",
        "기름기가 묻어있는 상태입니다",
        "오물이 부착된 상태입니다",
        "찌꺼기가 남아있는 상태입니다",
        "오염물이 있는 상태입니다",
        "더러운 흔적이 있는 상태입니다",
        "냄새가 나는 오염 상태입니다",
        "잔여물이 있는 상태입니다",
        "세척되지 않은 상태입니다",
        "불순물이 묻어있는 상태입니다",
        "오염으로 처리가 필요한 상태입니다",
        "내부가 오염된 상태입니다",
        "이물질로 오염된 상태입니다",
        "잔류물이 있는 상태입니다",
        "오물이 남아있는 상태입니다",
        "오염되어 재활용이 어려운 상태입니다",
        "이물질이 남아있는 상태입니다",
    ],

    # 다중포장재 3개
    'c_4_01_01': [
        "외부에 포장재가 부착된 상태입니다",
        "라벨이 결합되어 있는 상태입니다",
        "포장재가 분리되지 않은 상태입니다",
        "외부 포장이 있는 상태입니다",
        "뚜껑과 포장재가 결합된 상태입니다",
        "포장이 제거되지 않은 상태입니다",
        "복합 포장재가 있는 상태입니다",
        "분리가 필요한 포장 상태입니다",
        "외부 라벨이 부착된 상태입니다",
        "포장재가 겹쳐진 상태입니다",
        "추가 포장이 있는 상태입니다",
        "포장 분리가 필요한 상태입니다",
        "외부 포장이 결합된 상태입니다",
        "복합 재질이 있는 상태입니다",
        "포장재가 남아있는 상태입니다",
        "분리 배출이 필요한 포장 상태입니다",
        "포장이 결합되어 있는 상태입니다",
        "외부 부착물이 있는 상태입니다",
        "포장재가 있어 처리가 필요한 상태입니다",
        "포장 제거가 필요한 상태입니다",
    ],
    'c_4_02_01_01': [
        "외부에 포장재가 부착된 상태입니다",
        "라벨이 결합되어 있는 상태입니다",
        "포장재가 분리되지 않은 상태입니다",
        "외부 포장이 있는 상태입니다",
        "뚜껑과 포장재가 결합된 상태입니다",
        "포장이 제거되지 않은 상태입니다",
        "복합 포장재가 있는 상태입니다",
        "분리가 필요한 포장 상태입니다",
        "외부 라벨이 부착된 상태입니다",
        "포장재가 겹쳐진 상태입니다",
        "추가 포장이 있는 상태입니다",
        "포장 분리가 필요한 상태입니다",
        "외부 포장이 결합된 상태입니다",
        "복합 재질이 있는 상태입니다",
        "포장재가 남아있는 상태입니다",
        "분리 배출이 필요한 포장 상태입니다",
        "포장이 결합되어 있는 상태입니다",
        "외부 부착물이 있는 상태입니다",
        "포장재가 있어 처리가 필요한 상태입니다",
        "포장 제거가 필요한 상태입니다",
    ],
    'c_4_02_02_01': [
        "외부에 포장재가 부착된 상태입니다",
        "라벨이 결합되어 있는 상태입니다",
        "포장재가 분리되지 않은 상태입니다",
        "외부 포장이 있는 상태입니다",
        "뚜껑과 포장재가 결합된 상태입니다",
        "포장이 제거되지 않은 상태입니다",
        "복합 포장재가 있는 상태입니다",
        "분리가 필요한 포장 상태입니다",
        "외부 라벨이 부착된 상태입니다",
        "포장재가 겹쳐진 상태입니다",
        "추가 포장이 있는 상태입니다",
        "포장 분리가 필요한 상태입니다",
        "외부 포장이 결합된 상태입니다",
        "복합 재질이 있는 상태입니다",
        "포장재가 남아있는 상태입니다",
        "분리 배출이 필요한 포장 상태입니다",
        "포장이 결합되어 있는 상태입니다",
        "외부 부착물이 있는 상태입니다",
        "포장재가 있어 처리가 필요한 상태입니다",
        "포장 제거가 필요한 상태입니다",
    ],
    'c_4_02_03_01': [
        "외부에 포장재가 부착된 상태입니다",
        "라벨이 결합되어 있는 상태입니다",
        "포장재가 분리되지 않은 상태입니다",
        "외부 포장이 있는 상태입니다",
        "뚜껑과 포장재가 결합된 상태입니다",
        "포장이 제거되지 않은 상태입니다",
        "복합 포장재가 있는 상태입니다",
        "분리가 필요한 포장 상태입니다",
        "외부 라벨이 부착된 상태입니다",
        "포장재가 겹쳐진 상태입니다",
        "추가 포장이 있는 상태입니다",
        "포장 분리가 필요한 상태입니다",
        "외부 포장이 결합된 상태입니다",
        "복합 재질이 있는 상태입니다",
        "포장재가 남아있는 상태입니다",
        "분리 배출이 필요한 포장 상태입니다",
        "포장이 결합되어 있는 상태입니다",
        "외부 부착물이 있는 상태입니다",
        "포장재가 있어 처리가 필요한 상태입니다",
        "포장 제거가 필요한 상태입니다",
    ],
    'c_5_01': [
        "외부에 포장재가 부착된 상태입니다",
        "라벨이 결합되어 있는 상태입니다",
        "포장재가 분리되지 않은 상태입니다",
        "외부 포장이 있는 상태입니다",
        "뚜껑과 포장재가 결합된 상태입니다",
        "포장이 제거되지 않은 상태입니다",
        "복합 포장재가 있는 상태입니다",
        "분리가 필요한 포장 상태입니다",
        "외부 라벨이 부착된 상태입니다",
        "포장재가 겹쳐진 상태입니다",
        "추가 포장이 있는 상태입니다",
        "포장 분리가 필요한 상태입니다",
        "외부 포장이 결합된 상태입니다",
        "복합 재질이 있는 상태입니다",
        "포장재가 남아있는 상태입니다",
        "분리 배출이 필요한 포장 상태입니다",
        "포장이 결합되어 있는 상태입니다",
        "외부 부착물이 있는 상태입니다",
        "포장재가 있어 처리가 필요한 상태입니다",
        "포장 제거가 필요한 상태입니다",
    ],

    # 별도배출 3개
    'c_8_01': [
        "별도 수거가 필요한 상태입니다",
        "전용 수거함이 필요한 상태입니다",
        "일반 재활용이 불가한 상태입니다",
        "특수 처리가 필요한 상태입니다",
        "전용 배출이 필요한 상태입니다",
        "별도 처리가 필요한 상태입니다",
        "일반 쓰레기로 버릴 수 없는 상태입니다",
        "전용 장소에 배출해야 하는 상태입니다",
        "특별 수거가 필요한 상태입니다",
        "분리 배출이 필요한 상태입니다",
        "별도 배출함이 필요한 상태입니다",
        "일반 수거가 불가한 상태입니다",
        "전용 처리가 필요한 상태입니다",
        "특수 수거가 필요한 상태입니다",
        "별도로 처리해야 하는 상태입니다",
        "일반 배출이 불가한 상태입니다",
        "전용 배출함에 넣어야 하는 상태입니다",
        "특별 처리가 필요한 상태입니다",
        "별도 수거함이 필요한 상태입니다",
        "전용 수거가 필요한 상태입니다",
    ],
    'c_8_02': [
        "별도 수거가 필요한 상태입니다",
        "전용 수거함이 필요한 상태입니다",
        "일반 재활용이 불가한 상태입니다",
        "특수 처리가 필요한 상태입니다",
        "전용 배출이 필요한 상태입니다",
        "별도 처리가 필요한 상태입니다",
        "일반 쓰레기로 버릴 수 없는 상태입니다",
        "전용 장소에 배출해야 하는 상태입니다",
        "특별 수거가 필요한 상태입니다",
        "분리 배출이 필요한 상태입니다",
        "별도 배출함이 필요한 상태입니다",
        "일반 수거가 불가한 상태입니다",
        "전용 처리가 필요한 상태입니다",
        "특수 수거가 필요한 상태입니다",
        "별도로 처리해야 하는 상태입니다",
        "일반 배출이 불가한 상태입니다",
        "전용 배출함에 넣어야 하는 상태입니다",
        "특별 처리가 필요한 상태입니다",
        "별도 수거함이 필요한 상태입니다",
        "전용 수거가 필요한 상태입니다",
    ],
    'c_8_01_01': [
        "오염되어 별도 수거가 필요한 상태입니다",
        "이물질이 있어 전용 수거함이 필요합니다",
        "오염으로 일반 재활용이 불가한 상태입니다",
        "이물질로 특수 처리가 필요한 상태입니다",
        "오염되어 전용 배출이 필요한 상태입니다",
        "이물질로 별도 처리가 필요한 상태입니다",
        "오염되어 일반 배출이 불가한 상태입니다",
        "이물질로 전용 장소 배출이 필요합니다",
        "오염으로 특별 수거가 필요한 상태입니다",
        "이물질이 있어 분리 배출이 필요합니다",
        "오염되어 별도 배출함이 필요한 상태입니다",
        "이물질로 일반 수거가 불가한 상태입니다",
        "오염으로 전용 처리가 필요한 상태입니다",
        "이물질로 특수 수거가 필요한 상태입니다",
        "오염되어 별도로 처리해야 하는 상태입니다",
        "이물질로 일반 배출이 불가한 상태입니다",
        "오염되어 전용 배출함이 필요한 상태입니다",
        "이물질로 특별 처리가 필요한 상태입니다",
        "오염되어 별도 수거함이 필요한 상태입니다",
        "이물질로 전용 수거가 필요한 상태입니다",
    ],
    'c_9': [
        "별도 수거가 필요한 상태입니다",
        "전용 수거함이 필요한 상태입니다",
        "일반 재활용이 불가한 상태입니다",
        "특수 처리가 필요한 상태입니다",
        "전용 배출이 필요한 상태입니다",
        "별도 처리가 필요한 상태입니다",
        "일반 쓰레기로 버릴 수 없는 상태입니다",
        "전용 장소에 배출해야 하는 상태입니다",
        "특별 수거가 필요한 상태입니다",
        "분리 배출이 필요한 상태입니다",
        "별도 배출함이 필요한 상태입니다",
        "일반 수거가 불가한 상태입니다",
        "전용 처리가 필요한 상태입니다",
        "특수 수거가 필요한 상태입니다",
        "별도로 처리해야 하는 상태입니다",
        "일반 배출이 불가한 상태입니다",
        "전용 배출함에 넣어야 하는 상태입니다",
        "특별 처리가 필요한 상태입니다",
        "별도 수거함이 필요한 상태입니다",
        "전용 수거가 필요한 상태입니다",
    ],
}

# CSV 교체
import pandas as pd
import random

train_df = pd.read_csv(r'C:\BertEfficient_recycle\output\train.csv')
val_df = pd.read_csv(r'C:\BertEfficient_recycle\output\val.csv')
test_df = pd.read_csv(r'C:\BertEfficient_recycle\output\test.csv')

def assign_bert_text(df, seed=42):
    random.seed(seed)
    df = df.copy()
    df['bert_text'] = df['class_name'].apply(
        lambda c: random.choice(CLASS_BERT_TEXT.get(c, ["상태를 확인할 수 없습니다"]))
    )
    return df

train_df = assign_bert_text(train_df, seed=42)
val_df = assign_bert_text(val_df,   seed=43)
test_df = assign_bert_text(test_df,  seed=44)

train_df.to_csv(r'C:\BertEfficient_recycle\output\train.csv', index=False, encoding='utf-8-sig')
val_df.to_csv(r'C:\BertEfficient_recycle\output\val.csv',     index=False, encoding='utf-8-sig')
test_df.to_csv(r'C:\BertEfficient_recycle\output\test.csv',   index=False, encoding='utf-8-sig')

print('완료')
print(train_df[['class_name', 'bert_text']].head(10))
# Out:
# 완료
#      class_name              bert_text
# 0     c_4_01_01        외부 포장이 있는 상태입니다
# 1  c_4_02_01_01     외부에 포장재가 부착된 상태입니다
# 2     c_4_01_02            손상 없이 깨끗합니다
# 3        c_6_01        내용물이 남아있는 상태입니다
# 4  c_4_02_03_02        오물 없이 청결한 상태입니다
# 5        c_5_01     뚜껑과 포장재가 결합된 상태입니다
# 6        c_2_01        오염 없이 양호한 상태입니다
# 7           c_3         오염 흔적 없이 깨끗합니다
# 8        c_5_02         세척되어 청결한 상태입니다
# 9     c_4_01_01  포장재가 있어 처리가 필요한 상태입니다
